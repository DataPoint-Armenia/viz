# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#             ----- All the work is the intellectual property of DataPoint Armenia. -----

# %% [markdown]
# # Where and When did Armenians find Love the Most <3 ?

# %%
### Reading the dataset
### Sournce: armstat.org
marriages = pd.read_csv('mrg.csv').loc[23:252, :]
marriages
# Out:
#                State    Date  Marriages acts, total  \
# 23   Aragatsotn Marz  1996.0                  779.0
# 24   Aragatsotn Marz  1997.0                  536.0
# 25   Aragatsotn Marz  1998.0                  547.0
# 26   Aragatsotn Marz  1999.0                  568.0
# 27   Aragatsotn Marz  2000.0                  481.0
# ..               ...     ...                    ...
# 248      Tavush Marz  2014.0                  632.0
# 249      Tavush Marz  2015.0                  619.0
# 250      Tavush Marz  2016.0                  648.0
# 251      Tavush Marz  2017.0                  534.0
# 252      Tavush Marz  2018.0                  515.0
#
#      Marriages, rate, per 1000 population
# 23                                    5.6
# 24                                    3.9
# 25                                    3.9
# 26                                    4.1
# 27                                    3.5
# ..                                    ...
# ...

# %%
### converting the Date column into int 
marriages.Date = marriages.Date.astype(int)

# %%
plt.figure(figsize = (16,10))
sns.lineplot(x= 'Date', y = 'Marriages, rate, per 1000 population', hue = 'State', data = marriages)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Marriages rate, per 1000 population', fontsize=20)
plt.legend(loc=2, prop={'size': 12})
plt.show()

# %%
plt.figure(figsize = (16,10))
sns.violinplot(x="Date", y='Marriages, rate, per 1000 population', data = marriages)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Marriages rate, per 1000 population', fontsize=20)
plt.show()
# Out:
# /Users/mananahakobyan/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
